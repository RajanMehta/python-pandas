# %%
import pandas as pd

# %%
bond = pd.read_csv("data/jamesbond.csv")
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %% [markdown]
# ### Index operations

# %%
bond.set_index("Film").head(3)    #or use index_col while reading csv
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond.reset_index(drop=True).head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.set_index("Film", inplace=True)
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["Goldfinger"]
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
bond.loc["Casino Royale"]
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.loc["Diamonds Are Forever":"Moonraker"]
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
# Licence to Kill        1989  Timothy Dalton        John Glen       250.9
# Live and Let Die       1973     Roger Moore     Guy Hamilton       460.3
# Moonraker              1979     Roger Moore    Lewis Gilbert       535.0
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# ...

# %%
bond.loc[ ["Moonraker", "Octopussy"] ]
# Out:
#            Year        Actor       Director  Box Office  Budget  \
# Film
# Moonraker  1979  Roger Moore  Lewis Gilbert       535.0    91.5
# Octopussy  1983  Roger Moore      John Glen       373.8    53.9
#
#            Bond Actor Salary
# Film
# Moonraker                NaN
# Octopussy                7.8

# %%
bond.loc[ ["Gold Bond", "Octopussy"] ]  #Gold Bond does not exist in original dataFrame. But, it will be added here. Be careful.
# Out:
#              Year        Actor   Director  Box Office  Budget  \
# Film
# Gold Bond     NaN          NaN        NaN         NaN     NaN
# Octopussy  1983.0  Roger Moore  John Glen       373.8    53.9
#
#            Bond Actor Salary
# Film
# Gold Bond                NaN
# Octopussy                7.8

# %%
bond.loc["Moonraker", ["Actor", "Year"]]
# Out:
# Actor    Roger Moore
# Year            1979
# Name: Moonraker, dtype: object

# %%
bond.loc["Moonraker", "Actor":"Budget"]
# Out:
# Actor           Roger Moore
# Director      Lewis Gilbert
# Box Office              535
# Budget                 91.5
# Name: Moonraker, dtype: object

# %%
bond.iloc[0]   #retrieves rows at index position
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.iloc[ [5,10,15] ]
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# Licence to Kill                  1989  Timothy Dalton      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# Licence to Kill                       250.9    56.7                7.9
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
bond.iloc[14, 2]
# Out:
# 'John Glen'

# %%
bond.loc[bond["Actor"]=="Sean Connery", "Actor"] = "Sir Sean Connery"

# %%
bond.loc[["Dr. No", "Goldfinger"]]
# Out:
#             Year             Actor       Director  Box Office  Budget  \
# Film
# Dr. No      1962  Sir Sean Connery  Terence Young       448.8     7.0
# Goldfinger  1964  Sir Sean Connery   Guy Hamilton       820.4    18.6
#
#             Bond Actor Salary
# Film
# Dr. No                    0.6
# Goldfinger                3.2

# %% [markdown]
# ### Renaming

# %%
bond.rename(columns = {"Year":"Release Date", "Box Office": "Revenue"}).head(3)
# Out:
#                   Release Date         Actor         Director  Revenue  \
# Film
# A View to a Kill          1985   Roger Moore        John Glen    275.2
# Casino Royale             2006  Daniel Craig  Martin Campbell    581.5
# Casino Royale             1967   David Niven       Ken Hughes    315.0
#
#                   Budget  Bond Actor Salary
# Film
# A View to a Kill    54.5                9.1
# Casino Royale      145.3                3.3
# Casino Royale       85.0                NaN

# %%
bond.rename(index = {"Dr. No":"Doctor No"}, inplace=True)
bond.loc["Doctor No"]
# Out:
# Release Date                     1962
# Actor                Sir Sean Connery
# Director                Terence Young
# Revenue                         448.8
# Budget                              7
# Bond Actor Salary                 0.6
# Name: Doctor No, dtype: object

# %%
bond.columns
# Out:
# Index([u'Release Date', u'Actor', u'Director', u'Revenue', u'Budget',
#        u'Bond Actor Salary'],
#       dtype='object')

# %%
bond.columns = ['Date of Release', 'Actor', 'Director', 'Revenue', 'Budget', 'Salary']
bond.head(1)
# Out:
#                   Date of Release        Actor   Director  Revenue  Budget  \
# Film
# A View to a Kill             1985  Roger Moore  John Glen    275.2    54.5
#
#                   Salary
# Film
# A View to a Kill     9.1

# %% [markdown]
# ### Deletion

# %%
bond.drop(["A View to a Kill", "Casino Royale"])   #inplace=true necessary

bond.drop("Revenue", axis=1).head(1)
# Out:
#                   Date of Release        Actor   Director  Budget  Salary
# Film
# A View to a Kill             1985  Roger Moore  John Glen    54.5     9.1

# %%
actor = bond.pop("Actor")

# %%
bond.head(1)
# Out:
#                   Date of Release   Director  Revenue  Budget  Salary
# Film
# A View to a Kill             1985  John Glen    275.2    54.5     9.1

# %%
actor.head(1)
# Out:
# Film
# A View to a Kill    Roger Moore
# Name: Actor, dtype: object

# %%
del bond["Director"]

# %%
bond.head(1)
# Out:
#                   Date of Release  Revenue  Budget  Salary
# Film
# A View to a Kill             1985    275.2    54.5     9.1

# %% [markdown]
# ### Random Sample

# %%
bond.sample(n = 5)
# Out:
#                        Date of Release  Revenue  Budget  Salary
# Film
# Never Say Never Again             1983    380.0    86.0     NaN
# Quantum of Solace                 2008    514.2   181.4     8.1
# For Your Eyes Only                1981    449.4    60.2     NaN
# Casino Royale                     2006    581.5   145.3     3.3
# Die Another Day                   2002    465.4   154.2    17.9

# %%
bond.sample(frac = .25)
# Out:
#                       Date of Release  Revenue  Budget  Salary
# Film
# Moonraker                        1979    535.0    91.5     NaN
# Skyfall                          2012    943.5   170.2    14.5
# GoldenEye                        1995    518.5    76.9     5.1
# Doctor No                        1962    448.8     7.0     0.6
# The Spy Who Loved Me             1977    533.0    45.1     NaN
# Quantum of Solace                2008    514.2   181.4     8.1
# Tomorrow Never Dies              1997    463.2   133.9    10.0

# %%
bond.sample(n = 2, axis=1).head(3)
# Out:
#                   Revenue  Salary
# Film
# A View to a Kill    275.2     9.1
# Casino Royale       581.5     3.3
# Casino Royale       315.0     NaN

# %% [markdown]
# ### smallest and largest values

# %%
bond = pd.read_csv("data/jamesbond.csv", index_col="Film")

# %%
bond.nlargest(3, "Box Office")
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nsmallest(3, "Box Office")
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# A View to a Kill                 1985     Roger Moore      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# A View to a Kill                      275.2    54.5                9.1
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
bond["Box Office"].nlargest(3)
# Out:
# Film
# Skyfall        943.5
# Thunderball    848.1
# Goldfinger     820.4
# Name: Box Office, dtype: float64

# %% [markdown]
# ### other methods for filtering

# %%
bond.where( bond["Actor"] == "Sean Connery" )
# Out:
#                                    Year         Actor        Director  \
# Film
# Dr. No                           1962.0  Sean Connery   Terence Young
# From Russia with Love            1963.0  Sean Connery   Terence Young
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Thunderball                      1965.0  Sean Connery   Terence Young
# Casino Royale                       NaN           NaN             NaN
# You Only Live Twice              1967.0  Sean Connery   Lewis Gilbert
# On Her Majesty's Secret Service     NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Live and Let Die                    NaN           NaN             NaN
# The Man with the Golden Gun         NaN           NaN             NaN
# The Spy Who Loved Me                NaN           NaN             NaN
# Moonraker                           NaN           NaN             NaN
# ...

# %%
bond.query('Actor == "Sean Connery"')
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# You Only Live Twice                  4.4
# Diamonds Are Forever                 5.8
# ...

# %%
bond.query('Actor == "Roger Moore" and Director == "John Glen"')   #use "or" instead of |
# Out:
#                     Year        Actor   Director  Box Office  Budget  \
# Film
# For Your Eyes Only  1981  Roger Moore  John Glen       449.4    60.2
# Octopussy           1983  Roger Moore  John Glen       373.8    53.9
# A View to a Kill    1985  Roger Moore  John Glen       275.2    54.5
#
#                     Bond Actor Salary
# Film
# For Your Eyes Only                NaN
# Octopussy                         7.8
# A View to a Kill                  9.1

# %%
bond.query('Actor not in ["Sean Connery", "Roger Moore", "Pierce Brosnan"]')
# Out:
#                                  Year           Actor         Director  \
# Film
# Casino Royale                    1967     David Niven       Ken Hughes
# On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
# The Living Daylights             1987  Timothy Dalton        John Glen
# Licence to Kill                  1989  Timothy Dalton        John Glen
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# Quantum of Solace                2008    Daniel Craig     Marc Forster
# Skyfall                          2012    Daniel Craig       Sam Mendes
# Spectre                          2015    Daniel Craig       Sam Mendes
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Casino Royale                         315.0    85.0                NaN
# On Her Majesty's Secret Service       291.5    37.3                0.6
# The Living Daylights                  313.5    68.8                5.2
# ...

# %%
bond["Box Office"].mean()
# Out:
# 491.61153846153854

# %%
def successful_movie(row):
    revenue = row[3]
    if revenue > 492.0:
        return "successful"
    else:
        return "no clue"
        
bond.apply(successful_movie, axis=1)
# Out:
# Film
# Dr. No                                no clue
# From Russia with Love              successful
# Goldfinger                         successful
# Thunderball                        successful
# Casino Royale                         no clue
# You Only Live Twice                successful
# On Her Majesty's Secret Service       no clue
# Diamonds Are Forever                  no clue
# Live and Let Die                      no clue
# The Man with the Golden Gun           no clue
# The Spy Who Loved Me               successful
# Moonraker                          successful
# For Your Eyes Only                    no clue
# Never Say Never Again                 no clue
# Octopussy                             no clue
# A View to a Kill                      no clue
# The Living Daylights                  no clue
# Licence to Kill                       no clue
# GoldenEye                          successful
# Tomorrow Never Dies                   no clue
# ...

# %%
directors = bond["Director"].copy()
directors.head()
# Out:
# Film
# Dr. No                   Terence Young
# From Russia with Love    Terence Young
# Goldfinger                Guy Hamilton
# Thunderball              Terence Young
# Casino Royale               Ken Hughes
# Name: Director, dtype: object
