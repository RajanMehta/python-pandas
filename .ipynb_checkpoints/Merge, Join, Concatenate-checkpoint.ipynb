# %%
import pandas as pd

# %%
week1 = pd.read_csv("data/Restaurant/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("data/Restaurant/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("data/Restaurant/Restaurant - Customers.csv")
foods = pd.read_csv("data/Restaurant/Restaurant - Foods.csv")

# %%
#ignore_index=False : indexes are retained. we don't want that.
#sales = pd.concat([week1, week2], ignore_index = True)
sales = pd.concat([week1, week2], keys=["Week 1", "Week 2"])
sales
# Out:
#             Customer ID  Food ID
# Week 1 0            537        9
#        1             97        4
#        2            658        1
#        3            202        2
#        4            155        9
#        5            213        8
#        6            600        1
#        7            503        5
#        8             71        3
#        9            174        3
#        10           961        9
#        11           966        5
#        12           641        4
#        13           288        2
#        14           149        4
#        15           954        2
#        16           147        9
#        17           155        1
#        18           550        6
#        19           101        7
#        20           549        6
#        21            75        6
#        22            78        7
#        23           514        5
#        24           833        7
#        25           329        8
#        26           586       10
# ...

# %%
sales = week2.append(week1, ignore_index = True)
sales
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# 5            310        5
# 6            761        2
# 7            443        5
# 8            729        9
# 9            741        8
# 10           847        6
# 11           156       10
# 12           550        7
# 13           620       10
# 14           272        4
# 15           511        2
# 16             8        6
# 17           534        7
# 18           909        6
# 19           732        9
# 20           372        4
# 21           713        1
# 22           496        3
# 23           381        9
# 24            13        2
# 25           101        4
# 26           325        7
# 27           674        2
# 28           564        8
# 29           578        5
# ..           ...      ...
# 470          147        8
# 471          745        4
# 472          184        3
# ...

# %% [markdown]
# ### Inner Join

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
week1.merge(week2, how="inner", on="Customer ID").head()
# Out:
#    Customer ID  Food ID_x  Food ID_y
# 0          537          9          5
# 1          155          9          3
# 2          155          1          3
# 3          503          5          8
# 4          503          5          9

# %%
week1.merge(week2, how="inner", on=["Customer ID", "Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %% [markdown]
# ### Outer Join

# %%
week1.merge(week2, how="outer", on="Customer ID", suffixes = [" - Week 1", " - Week 2"], indicator = True)
# Out:
#      Customer ID  Food ID - Week 1  Food ID - Week 2      _merge
# 0            537               9.0               5.0        both
# 1             97               4.0               NaN   left_only
# 2            658               1.0               NaN   left_only
# 3            202               2.0               NaN   left_only
# 4            155               9.0               3.0        both
# 5            155               1.0               3.0        both
# 6            213               8.0               NaN   left_only
# 7            600               1.0               NaN   left_only
# 8            503               5.0               8.0        both
# 9            503               5.0               9.0        both
# 10            71               3.0               NaN   left_only
# 11            71               8.0               NaN   left_only
# 12           174               3.0               NaN   left_only
# ...

# %%
merged = week1.merge(week2, how="outer", on="Customer ID", suffixes = [" - Week 1", " - Week 2"], indicator = True)
merged["_merge"].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
merged[ merged["_merge"].isin(["left_only","right_only"]) ]
# Out:
#      Customer ID  Food ID - Week 1  Food ID - Week 2      _merge
# 1             97               4.0               NaN   left_only
# 2            658               1.0               NaN   left_only
# 3            202               2.0               NaN   left_only
# 6            213               8.0               NaN   left_only
# 7            600               1.0               NaN   left_only
# 10            71               3.0               NaN   left_only
# 11            71               8.0               NaN   left_only
# 12           174               3.0               NaN   left_only
# 13           961               9.0               NaN   left_only
# 14           966               5.0               NaN   left_only
# 15           641               4.0               NaN   left_only
# 16           288               2.0               NaN   left_only
# 17           149               4.0               NaN   left_only
# ...

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
customers.head(2)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer

# %%
#use right_index instead of right_on if "ID" is index and not a column

week2.merge(customers, how="left", left_on="Customer ID", right_on="ID").drop("ID", axis="columns").head()
# Out:
#    Customer ID  Food ID First Name   Last Name  Gender     Company  \
# 0          688       10       Carl  Williamson    Male  Thoughtmix
# 1          813        7     Johnny      Walker    Male      Kayveo
# 2          495       10    Deborah      Little  Female  Babbleblab
# 3          189        5      Roger      Gordon    Male     Skilith
# 4          267        3    Matthew        Wood    Male      Agimba
#
#          Occupation
# 0  Graphic Designer
# 1      Developer II
# 2     VP Accounting
# 3          Operator
# 4  Product Engineer
